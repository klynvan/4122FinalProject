# %%
import streamlit as st
import pandas as pd
import numpy as np
import altair as alt
import seaborn as sns

# %%
df = pd.read_csv ('combined.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 144       Rwanda               Sub-Saharan Africa             145
# 145        Benin               Sub-Saharan Africa             146
# 146        Syria  Middle East and Northern Africa             147
# 147      Burundi               Sub-Saharan Africa             148
# 148         Togo               Sub-Saharan Africa             149
#
#      Happiness Score  Standard Error   Family  Freedom  \
# 0              7.587         0.03411  1.34951  0.66557
# 1              7.561         0.04884  1.40223  0.62877
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error      Family  \
# count      149.000000       149.000000      149.000000  149.000000
# mean        75.000000         5.376758        0.047441    0.990920
# std         43.156691         1.171099        0.017196    0.279754
# min          1.000000         2.839000        0.018480    0.000000
# 25%         38.000000         4.514000        0.036760    0.851880
# 50%         75.000000         5.212000        0.043610    1.032760
# 75%        112.000000         6.295000        0.051410    1.223930
# max        149.000000         7.587000        0.136930    1.402230
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  149.000000                     149.000000  149.000000
# mean     0.433152                       0.142509    0.235738
# std      0.149994                       0.119525    0.127276
# min      0.000000                       0.000000    0.000000
# ...

# %%
testdf = df.drop(["Country", "Region"], axis=1)
testdf
# Out:
#      Happiness Rank  Happiness Score  Standard Error   Family  Freedom  \
# 0                 1            7.587         0.03411  1.34951  0.66557
# 1                 2            7.561         0.04884  1.40223  0.62877
# 2                 3            7.527         0.03328  1.36058  0.64938
# 3                 4            7.522         0.03880  1.33095  0.66973
# 4                 5            7.427         0.03553  1.32261  0.63297
# ..              ...              ...             ...      ...      ...
# 144             145            3.465         0.03464  0.77370  0.59201
# 145             146            3.340         0.03656  0.35386  0.48450
# 146             147            3.006         0.05015  0.47489  0.15684
# 147             148            2.905         0.08658  0.41587  0.11850
# 148             149            2.839         0.06727  0.13995  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year  \
# ...

# %%
sns.pairplot(testdf)

# %%
sns.heatmap(testdf, annot=True)
# Out:
# <AxesSubplot:>
